# %%
import numpy as np
import sys
import torch  
sys.path.insert(0, '..')

# %%
from src.utilities import *
from src.visualization.visualize import *
from src.network import LossNet

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
image = load_image("../images/content/obrien.jpg")
loss = LossNet(requires_grad=False).to(device)

# %%
outputs = loss(image)

# %%
# Out:
# tensor([[[[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0363, 0.0337,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0269, 0.0254,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#          [[0.0403, 0.6148, 0.6392,  ..., 0.3100, 0.3636, 0.4665],
#           [0.0000, 0.2946, 0.3050,  ..., 0.2722, 0.3180, 0.4609],
#           [0.0000, 0.3005, 0.3021,  ..., 0.2882, 0.3373, 0.4852],
#           ...,
#           [0.0000, 0.3331, 0.3463,  ..., 0.3289, 0.3875, 0.5444],
#           [0.0000, 0.2599, 0.2510,  ..., 0.2243, 0.3441, 0.5716],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0615, 0.1261, 0.3645]],
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#          ...,
#
#          [[0.1703, 0.1715, 0.1742,  ..., 0.0000, 0.0000, 0.0000],
#           [0.3229, 0.3666, 0.3634,  ..., 0.0000, 0.0000, 0.0000],
#           [0.3287, 0.3675, 0.3668,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0406, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0341, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#          [[0.0689, 0.0501, 0.0558,  ..., 0.2619, 0.2257, 0.1889],
#           [0.1575, 0.2965, 0.2687,  ..., 0.3308, 0.3010, 0.2554],
#           [0.1624, 0.2866, 0.2942,  ..., 0.2916, 0.2859, 0.2598],
#           ...,
#           [0.5505, 0.3178, 0.3090,  ..., 0.2575, 0.2791, 0.2555],
#           [0.5143, 0.2324, 0.2451,  ..., 0.3134, 0.2839, 0.2505],
#           [0.1777, 0.0000, 0.0000,  ..., 0.2912, 0.2854, 0.2338]],
#
#          [[0.1374, 0.0000, 0.0000,  ..., 0.5082, 0.5157, 0.5254],
#           [0.6847, 0.3898, 0.4174,  ..., 0.4632, 0.4262, 0.4682],
#           [0.6780, 0.3890, 0.3829,  ..., 0.4552, 0.4127, 0.4402],
#           ...,
#           [1.1124, 0.4366, 0.4035,  ..., 0.4146, 0.3949, 0.4563],
#           [1.0916, 0.4327, 0.3990,  ..., 0.4046, 0.4261, 0.4396],
#           [0.6325, 0.1781, 0.1573,  ..., 0.2910, 0.3198, 0.3716]]]],
#        grad_fn=<ReluBackward1>)
