# %%
import numpy as np
import sys
import torch  
sys.path.insert(0, '..')

# %%
from src.visualization.visualize_style import visualize_style
from src.visualization.visualize import show_image
from src.utilities import save_image

# %%
style = visualize_style('conv4_3', '../images/style/style_small.jpg')
# Out:
# Epoch: 0 Loss: 8900825841664.0
# Epoch: 50 Loss: 29414795264.0
# Epoch: 100 Loss: 19830106112.0
# Epoch: 150 Loss: 74196598784.0
# Epoch: 199 Loss: 14723919872.0

# %%
image = style.cpu().clone() 
show_image(image)

# %%
image = style.cpu().clone() 
show_image(image)

# %%
image = style.cpu()
save_image("image.jpg",image)

# %%
from src.utilities import save_image, load_image

# %%
from src.network import Normalization
norm = Normalization()
img = load_image("../images/content/obrien_small.jpg")
norm(img)
# Out:
# tensor([[[[-2.1179, -2.1179, -2.1179,  ..., -2.0152, -1.9638, -1.9467],
#           [-2.1179, -2.1179, -2.1179,  ..., -1.9809, -2.0152, -1.8610],
#           [-2.1179, -2.1179, -2.1179,  ..., -2.0494, -1.9124, -2.0152],
#           ...,
#           [ 1.4440,  1.4612,  1.4954,  ..., -1.6898, -1.7240, -1.7583],
#           [ 1.5297,  1.5297,  1.5125,  ..., -1.6727, -1.7240, -1.7754],
#           [ 1.4954,  1.4783,  1.4612,  ..., -1.6213, -1.6898, -1.7583]],
#
#          [[-0.4601, -0.4601, -0.4601,  ..., -1.9482, -1.8606, -1.8256],
#           [-0.4601, -0.4601, -0.4601,  ..., -1.8782, -1.8606, -1.7031],
#           [-0.4601, -0.4601, -0.4601,  ..., -1.8957, -1.7031, -1.8081],
#           ...,
#           [ 1.5182,  1.5357,  1.5707,  ..., -1.5105, -1.5455, -1.5805],
#           [ 1.6057,  1.6057,  1.5882,  ..., -1.4930, -1.5455, -1.5980],
#           [ 1.5707,  1.5532,  1.5357,  ..., -1.4405, -1.5105, -1.5805]],
#
# ...

# %%
from torchvision import models
models.vgg19().features.parameters
# Out:
# <bound method Module.parameters of Sequential(
#   (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): ReLU(inplace=True)
#   (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (3): ReLU(inplace=True)
#   (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (6): ReLU(inplace=True)
#   (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (8): ReLU(inplace=True)
#   (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (11): ReLU(inplace=True)
#   (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (13): ReLU(inplace=True)
#   (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (15): ReLU(inplace=True)
# ...
