# %%
import tensorflow as tf
import numpy as np
import sys  
sys.path.insert(0, '..')

# %%
from src.train_once import *

# %%
generate_pastische("../images/style/style_small.jpg","../images/content/obrien_small.jpg",ipython=True)
# Out:
# Iterations: 0 Style Loss 636272.9375 Content Loss 0.0
# Iterations: 50 Style Loss 247608.265625 Content Loss 27.805814743041992
# <tf.Variable 'Variable:0' shape=(1, 512, 512, 3) dtype=float32, numpy=
# array([[[[ 0.01774177,  0.34662816,  0.56310874],
#          [-0.0035802 ,  0.3336946 ,  0.56328195],
#          [ 0.00967954,  0.34396726,  0.5635623 ],
#          ...,
#          [ 0.07702094,  0.0316314 , -0.04363001],
#          [ 0.08418076,  0.02908667, -0.04150895],
#          [ 0.07812619,  0.03769195, -0.05323766]],
#
#         [[ 0.04887802,  0.39509895,  0.5485112 ],
#          [ 0.03112777,  0.3560317 ,  0.555645  ],
#          [ 0.0502607 ,  0.38823363,  0.55540615],
#          ...,
#          [ 0.05595388,  0.04382312, -0.042106  ],
#          [ 0.04946214,  0.02502943, -0.04098056],
#          [ 0.09870066,  0.06342835, -0.0269373 ]],
#
#         [[ 0.0354653 ,  0.3793521 ,  0.59553516],
#          [ 0.037671  ,  0.3801427 ,  0.57350224],
# ...
